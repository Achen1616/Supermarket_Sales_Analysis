# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pig_data = pd.read_csv("../Output/Pig/AvgGrossIncomeByCity/part-r-00000.csv")
hive_data = pd.read_csv("../Output/Hive/Simple_Queries/AvgGrossIncomeByCity/000000_0.csv")

# %%
pig_data
# Out:
#         City  Avg_Gross_Income
# 0     Yangon         14.873853
# 1   Mandalay         15.232590
# 2  Naypyitaw         16.052287

# %%
hive_data
# Out:
#         City  Avg_Gross_Income
# 0   Mandalay         15.232024
# 1  Naypyitaw         16.052367
# 2     Yangon         14.874001

# %%
plt.figure(figsize=(10, 6))
plt.bar(pig_data['City'], pig_data['Avg_Gross_Income'], color='skyblue')
plt.xlabel('City')
plt.ylabel('Average Gross Income')
plt.title('Average Gross Income by City')
plt.show()
